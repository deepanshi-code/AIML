# %%
import pandas as pd
dataset={"Types_OF_Houses":["Flat","House","Flat","Flat","Flat","House","House","Flat","House","Flat","Flat","House","Flat","Flat"],"Size_of_House_BHK":[2,3,3,2,3,4,3,3,3,3,2,3,2,2],"Area_of_residence":[200,300,150,300,250,300,200,300,500,400,300,200,300,200],"prices_Lakhs":[13,12,140,15,16,12,13,124,15,16,102,13,15,16]}
housing_prices=pd.DataFrame(dataset)
print(housing_prices)
# Out:
#    Types_OF_Houses  Size_of_House_BHK  Area_of_residence  prices_Lakhs
# 0             Flat                  2                200            13
# 1            House                  3                300            12
# 2             Flat                  3                150           140
# 3             Flat                  2                300            15
# 4             Flat                  3                250            16
# 5            House                  4                300            12
# 6            House                  3                200            13
# 7             Flat                  3                300           124
# 8            House                  3                500            15
# 9             Flat                  3                400            16
# 10            Flat                  2                300           102
# 11           House                  3                200            13
# ...

# %%
m=min(housing_prices["Area_of_residence"])
n=max(housing_prices["Area_of_residence"])
l=[]
for i in housing_prices["Area_of_residence"]:
    x=(i-n)/(m-n)
    l.append(x)
housing_prices["Normalized_Area"]=l
print(housing_prices)
# Out:
#    Types_OF_Houses  Size_of_House_BHK  Area_of_residence  prices_Lakhs  \
# 0             Flat                  2                200            13
# 1            House                  3                300            12
# 2             Flat                  3                150           140
# 3             Flat                  2                300            15
# 4             Flat                  3                250            16
# 5            House                  4                300            12
# 6            House                  3                200            13
# 7             Flat                  3                300           124
# 8            House                  3                500            15
# 9             Flat                  3                400            16
# 10            Flat                  2                300           102
# 11           House                  3                200            13
# ...

# %%
m=min(housing_prices["prices_Lakhs"])
n=max(housing_prices["prices_Lakhs"])
l=[]
for i in housing_prices["prices_Lakhs"]:
    x=(i-n)/(m-n)
    l.append(x)
housing_prices["Normalized_price"]=l
print(housing_prices)
# Out:
#    Types_OF_Houses  Size_of_House_BHK  Area_of_residence  prices_Lakhs  \
# 0             Flat                  2                200            13
# 1            House                  3                300            12
# 2             Flat                  3                150           140
# 3             Flat                  2                300            15
# 4             Flat                  3                250            16
# 5            House                  4                300            12
# 6            House                  3                200            13
# 7             Flat                  3                300           124
# 8            House                  3                500            15
# 9             Flat                  3                400            16
# 10            Flat                  2                300           102
# 11           House                  3                200            13
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(housing_prices["Area_of_residence"],housing_prices["Normalized_Area"])
plt.xlabel("Actual_Area")
plt.ylabel("Normalized_Area")
plt.show()

# %%
plt.figure()
plt.bar(housing_prices["Area_of_residence"],housing_prices["Normalized_Area"])
plt.xlabel("Actual_Area")
plt.ylabel("Normalized_Area")
plt.show()

# %%
plt.figure()
plt.plot(housing_prices["prices_Lakhs"],housing_prices["Normalized_price"])
plt.xlabel("Actual_Area")
plt.ylabel("Normalized_Area")
plt.show()
